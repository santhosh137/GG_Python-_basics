# %%
### Logical operators and splitting strings

# %%
### split with space

str="Geeks Geek2 Geek3"

l=str.split()

print(l)
# Out:
# ['Geeks', 'Geek2', 'Geek3']

# %%
### split with comma
str="Geeks,Geek2,Geek3"

l=str.split(",")
print (l)
# Out:
# ['Geeks', 'Geek2', 'Geek3']

# %%
### split with comma
str="Geeks,Geek2,Geek3"

l=str.split(",",1)
print (l)
# Out:
# ['Geeks', 'Geek2,Geek3']

# %%
### logical operators


str1=""
str2="geeksforgeeks"
str3="geeks"

print ("str1:",str1)
print ("str2:",str2)
print ("str3:",str3)

print("str1 and str2:", str1 and str2)

print("str1 or str2:", str1 or str2)


print("str2 and str1:", str2 and str1)

print("str2 or str1:", str2 or str1)

print("str2 and str3:", str2 and str3)

print("str2 or str3:", str2 or str3)


print("str3 and str2:", str3 and str2)

print("str3 or str2:", str3 or str2)
# Out:
# str1:
# str2: geeksforgeeks
# str3: geeks
# str1 and str2:
# str1 or str2: geeksforgeeks
# str2 and str1:
# str2 or str1: geeksforgeeks
# str2 and str3: geeks
# str2 or str3: geeksforgeeks
# str3 and str2: geeksforgeeks
# str3 or str2: geeks
