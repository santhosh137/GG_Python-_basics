# %%
### Dictionary 

## Dictionary is similar to hash or map functions

## it h as key and value pairs


d=dict()

print (d)

d['xyz']=1
d['abc']=2

d['lmn']=3

print (d)
# Out:
# {}
# {'xyz': 1, 'abc': 2, 'lmn': 3}

# %%
print (d.keys())
# Out:
# dict_keys(['xyz', 'abc', 'lmn'])

# %%
print (d.values())
# Out:
# dict_values([2, 3])

# %%
print (d)
# Out:
# {'xyz': 1, 'abc': 2, 'lmn': 3}

# %%
del d['xyz']
print (d)
# Out:
# {'abc': 2, 'lmn': 3}

# %%
k={'xyz':1,"abc":2,'def':3}

print (k)

print ('xyz' in k)
# Out:
# {'xyz': 1, 'abc': 2, 'def': 3}
# True

# %%
##### 15

## len function for dictionary

d={'abc': 1, 'cde': 2,'fgh':3}


print (d)

print (len(d))
# Out:
# {'abc': 1, 'cde': 2, 'fgh': 3}
# 3

# %%
## converting a dictionary to string

d={'abc': 1,'def':2,'fgh':3}

str1=str(d)
print (str1)
print(type(str1))

print(str1[0:5:1])
# Out:
# {'abc': 1, 'def': 2, 'fgh': 3}
# <class 'str'>
# {'abc

# %%
### items in dictionary

d={'abc': 1,'def':2,'fgh':3}

print(d.items())
# Out:
# dict_items([('abc', 1), ('def', 2), ('fgh', 3)])

# %%
### copy and clear the dictionary
d1={'abc': 1,'def':2,'fgh':3}
d2={}

d2=d1.copy()


print(d1)

print (d2)
d1.clear()

print (d1)

print (d2)
# Out:
# {'abc': 1, 'def': 2, 'fgh': 3}
# {'abc': 1, 'def': 2, 'fgh': 3}
# {}
# {'abc': 1, 'def': 2, 'fgh': 3}

# %%
#### 16 

## update a dictionary


d1={'name': 'aneesh','age':14}

d2={"Rooll No": 123}

d1.update(d2)


print (d1)
# Out:
# {'name': 'aneesh', 'age': 14, 'Rooll No': 123}

# %%
### get defualt fucntion 

d1={'Name': 'Aneesh'}

print (d1.get('Name',"not present"))
print (d1.get('roll_no','not present'))
print(d1)
# Out:
# Aneesh
# not present
# {'Name': 'Aneesh'}

# %%
### set default fucntion 

d1={'Name': 'Aneesh'}

print (d1.setdefault('Name',"not present"))
print (d1.setdefault('roll_no','not present'))
print(d1)
# Out:
# Aneesh
# not present
# {'Name': 'Aneesh', 'roll_no': 'not present'}
