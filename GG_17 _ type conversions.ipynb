# %%
## Type conversion

# %%
a="10001"

print (type(a))

print (int(a,2))
print (int(a,10))

print (float(a))
print (float(a))
# Out:
# <class 'str'>
# 17
# 10001
# 10001.0
# 10001.0

# %%
#### ord , hex () and oct ()

# ord converts integer to ASCII value

#hex - hexadecimaal

#oct -ocatal 
char=' '

num=56

print (ord(char))

print (hex(num))

print (oct(num))
# Out:
# 32
# 0x38
# 0o70

# %%
### converting data types to lists, tuples and sets

# %%
str1="Geeks"

print (tuple(str1))

print (set(str1))

print (list(str1))
# Out:
# ('G', 'e', 'e', 'k', 's')
# {'e', 'G', 's', 'k'}
# ['G', 'e', 'e', 'k', 's']

# %%
### str  and complex (real, imag)

print ('complex nuber', complex(1,4))

str1=str(1211)

print (str1[0:2:1])
print (str1[0:3:1])
# Out:
# complex nuber (1+4j)
# 12
# 121
