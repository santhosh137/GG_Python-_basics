# %%
### Increment and decrement operator in pyhton

# %%
x=4
x+=1

print (x)
x-=2

print (x)
# Out:
# 5
# 3

# %%
## division operation in python

# %%
print (5/2)

print (int (5//2))
# Out:
# 2.5
# 2

# %%
#### any and all operators

l1=[False,False, False]
l2=[True,True, True]
l3=[False, True, True]

print (any(l1))
print (any(l2))
print (any(l3))

print (all(l1))
print (all(l2))
print (all(l3))
# Out:
# False
# True
# True
# False
# True
# False
