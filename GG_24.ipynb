# %%
#### Acessing the values f counters

# %%
from collections import Counter

z=['blue','red','blue','yellow','blue','red']

col_count=Counter(z)

print (col_count)
# Out:
# Counter({'blue': 3, 'red': 2, 'yellow': 1})

# %%
col=['blue','red','yellow','green']

for color in col:
  print (color,col_count[color])
# Out:
# blue 3
# red 2
# yellow 1
# green 0

# %%
from collections import Counter

coun=Counter(a=1,b=2,c=3)

print (coun)

print (list (coun.elements()))
# Out:
# Counter({'c': 3, 'b': 2, 'a': 1})
# ['a', 'b', 'b', 'c', 'c', 'c']

# %%
##most common functions are used to produce frequently enter the input values and commands

###most_common() is used to produce a sequence of the n most frequently encountered input values and their respective counts.

# %%
from collections import Counter
coun=Counter(a=1,b=2,c=1,d=120,e=1,f=219)

for letter, count in coun.most_common(3):
  print('%s:%d'%(letter,count))
# Out:
# f:219
# d:120
# b:2
