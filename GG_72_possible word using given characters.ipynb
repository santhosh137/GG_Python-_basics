# %%
## sample input

"""
dict=["go","bat","me","eat","goal","boy","run"]

arr=['e','o','b','a','m','g','l']

"""

## sample output

"""
go,me, goal

"""
# Out:
# '\ngo,me, goal\n\n'

# %%
def possible_word(arr,dict):
  for i in range(len(dict)):
    s=""
    for j in Dict[i]:
      if j in arr:
        s=s+j
      else:
        pass
    if s==Dict[i]:
      print (s)
    else:
      pass
    
  
      
        

Dict=["go","bat","me","eat","goal","boy","run"]

arr=['e','o','b','a','m','g','l']

print (type(Dict))

possible_word(arr,Dict)
# Out:
# <class 'list'>
# go
# me
# goal

# %%
def possiblewords(input,charset):
  print (type(Dict))
  from collections import Counter
  for word in input:
    dict=Counter(word)
    flag=1
    for key in dict.keys():
      if key not in charset:
        flag=0

    if flag==1:
      print (word)

Dict=["go","bat","me","eat","goal","boy","run"]

arr=['e','o','b','a','m','g','l']



possiblewords(Dict,arr)
# Out:
# <class 'list'>
# go
# me
# goal
