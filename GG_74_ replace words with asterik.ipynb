# %%
### sample Input

"""
word=Computer


text ="GeeksforGeeks is a computer science portal for geeks. 
people who love computer and computer codes can contribute their valuable ideas on computer codes on here.
"""

### sample utput

"""
word=Computer


text ="GeeksforGeeks is a ******** science portal for geeks. 
people who love ******** and ******** codes can contribute their valuable ideas on ******** codes on here.
"""
# Out:
# '\nword=Computer\n\n\ntext ="GeeksforGeeks is a ******** science portal for geeks. \npeople who love ******** and ******** codes can contribute their valuable ideas on ******** codes on here.\n'

# %%
text ="""
GeeksforGeeks is a computer science portal for geeks. 
People who love computer and computer codes can contribute their valuable ideas on computer codes on here.
"""

# %%
print (type(text))
# Out:
# <class 'str'>

# %%
text.replace('computer',"********")
print (text)
# Out:
# GeeksforGeeks is a computer science portal for geeks.
# People who love computer and computer codes can contribute their valuable ideas on computer codes on here.
