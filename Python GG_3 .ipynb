# %%
## Variabkles , Expressions , Conditions and Functions

# %%
# variables  used directly   and need not  to be declared and case sensitive

a=2
A=3

print (a)
print (A)
# Out:
# 2
# 3

# %%
## Arithmentic operations

# %%
a=2
A=3

print (a+A)
print (a*A)
print (a/A)
# Out:
# 5
# 6
# 0.6666666666666666

# %%
##Condional statements

a=2

if a%2==0:
  print ("a is even")
elif a%2!=0:
  print ("a is odd")
# Out:
# a is even

# %%
##Functions

# %%
def check_odd_or_even (a):
  if a%2==0:
    print ("a is even")
  elif a%2!=0:
    print ("a is odd")

check_odd_or_even (3)
# Out:
# a is odd
