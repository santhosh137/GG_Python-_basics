# %% [markdown]
# IDLE or online editor
#
# Download python software from python.org
#
# pLease use python 3 for advanced

# %%
# Print functions
#code begins

print ("Geeks for Geeks")
# Out:
# Geeks for Geeks
